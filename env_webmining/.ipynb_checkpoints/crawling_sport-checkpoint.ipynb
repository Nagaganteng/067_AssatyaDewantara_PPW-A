# %%
# !pip install requests beautifulsoup4 pandas lxml tqdm
# Out:
# Requirement already satisfied: requests in c:\ppw\env_webmining\lib\site-packages (2.34.2)
# Requirement already satisfied: beautifulsoup4 in c:\ppw\env_webmining\lib\site-packages (4.15.0)
# Requirement already satisfied: pandas in c:\ppw\env_webmining\lib\site-packages (3.0.5)
# Requirement already satisfied: lxml in c:\ppw\env_webmining\lib\site-packages (6.1.3)
# Collecting tqdm
#   Downloading tqdm-4.70.0-py3-none-any.whl (80 kB)
#      -------------------------------------- 80.2/80.2 kB 641.7 kB/s eta 0:00:00
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\ppw\env_webmining\lib\site-packages (from requests) (3.5.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\ppw\env_webmining\lib\site-packages (from requests) (3.19)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\ppw\env_webmining\lib\site-packages (from requests) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\ppw\env_webmining\lib\site-packages (from requests) (2026.7.22)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\ppw\env_webmining\lib\site-packages (from beautifulsoup4) (2.9.2)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\ppw\env_webmining\lib\site-packages (from beautifulsoup4) (4.16.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\ppw\env_webmining\lib\site-packages (from pandas) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\ppw\env_webmining\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\ppw\env_webmining\lib\site-packages (from pandas) (2026.3)
# Requirement already satisfied: colorama in c:\ppw\env_webmining\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\ppw\env_webmining\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Installing collected packages: tqdm
# Successfully installed tqdm-4.70.0
# [notice] A new release of pip available: 22.3 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from tqdm import tqdm
from urllib.parse import urljoin
import time

# %%
urls = [
    "https://sport.detik.com/sepakbola/liga-inggris",
    "https://sport.detik.com/sepakbola/liga-italia"
]

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/139.0.0.0 Safari/537.36"
}

for url in urls:
    response = requests.get(url, headers=headers, timeout=10)

    print("URL:", url)
    print("Status Code:", response.status_code)
    print("Panjang halaman:", len(response.text))
    print("-" * 50)
# Out:
# URL: https://sport.detik.com/sepakbola/liga-inggris
# Status Code: 200
# Panjang halaman: 273213
# --------------------------------------------------
# URL: https://sport.detik.com/sepakbola/liga-italia
# Status Code: 200
# Panjang halaman: 274026
# --------------------------------------------------

# %%
for url in urls:
    response = requests.get(url, headers=headers, timeout=10)
    
    soup = BeautifulSoup(response.text, "html.parser")
    
    print("URL:", url)
    print("Judul halaman:", soup.title.get_text(strip=True))
    print("-" * 50)
# Out:
# URL: https://sport.detik.com/sepakbola/liga-inggris
# Judul halaman: Informasi Berita Seputar Sepakbola Liga Inggris Terlengkap
# --------------------------------------------------
# URL: https://sport.detik.com/sepakbola/liga-italia
# Judul halaman: Informasi Berita Seputar Sepakbola Liga Italia Terlengkap
# --------------------------------------------------

# %%
data_link = []

for url in urls:
    response = requests.get(url, headers=headers, timeout=10)
    soup = BeautifulSoup(response.text, "html.parser")
    
    links = soup.find_all("a", href=True)

    for link in links:
        href = link["href"]
        text = link.get_text(" ", strip=True)

        if (
            "sport.detik.com/sepakbola/liga-inggris/" in href
            or "sport.detik.com/sepakbola/liga-italia/" in href
        ):
            if "/d-" in href and text:
                data_link.append({
                    "judul": text,
                    "url": href
                })

    print("Selesai crawling:", url)

df_link = pd.DataFrame(data_link)

# Hilangkan URL yang sama
# 100  https://sport.detik.com/sepakbola/liga-italia/...
# 101  https://sport.detik.com/sepakbola/liga-italia/...
#
# [102 rows x 2 columns]

# %%
df_artikel = df_link[
    (
        df_link["url"].str.contains("/sepakbola/liga-inggris/", na=False)
        |
        df_link["url"].str.contains("/sepakbola/liga-italia/", na=False)
    )
    &
    df_link["url"].str.contains("/d-", na=False)
].copy()

# Hilangkan URL duplikat
df_artikel = df_artikel.drop_duplicates(subset="url")

# Reset index
df_artikel = df_artikel.reset_index(drop=True)

print("Jumlah artikel Liga Inggris + Liga Italia:", len(df_artikel))
# Out:
# Jumlah artikel Liga Inggris + Liga Italia: 102

# %%
df_artikel.head(10)
# Out:
#                                                judul  \
# 0  Enzo Fernandez Bahagia Banget Tetap Dilatih Ma...
# 1  Haaland Minim Pramusim, Khawatir Performanya T...
# 2                    Carrick Sebut MU Baik-baik saja
# 3  Xabi Alonso Redam Isu Estevao Mau Cabut dari C...
# 4      Michael Carrick Puas dengan Performa Rashford
# 5  Mac Allister Sedih Tak Ditawari Kontrak Baru d...
# 6  Millwall Vs Newcastle: Elkan Baggott Main Penu...
# 7                     Arsenal Makin Pede Main Cantik
# 8      Ederson Angkat Bicara soal Batal Gabung ke MU
# 9                           Ada Apa dengan Garnacho?
#
#                                                  url
# 0  https://sport.detik.com/sepakbola/liga-inggris...
# 1  https://sport.detik.com/sepakbola/liga-inggris...
# 2  https://sport.detik.com/sepakbola/liga-inggris...
# 3  https://sport.detik.com/sepakbola/liga-inggris...
# 4  https://sport.detik.com/sepakbola/liga-inggris...
# 5  https://sport.detik.com/sepakbola/liga-inggris...
# 6  https://sport.detik.com/sepakbola/liga-inggris...
# 7  https://sport.detik.com/sepakbola/liga-inggris...
# 8  https://sport.detik.com/sepakbola/liga-inggris...
# 9  https://sport.detik.com/sepakbola/liga-inggris...

# %%
df_artikel = df_artikel.head(100)

print("Jumlah artikel yang akan di-crawl:", len(df_artikel))
# Out:
# Jumlah artikel yang akan di-crawl: 100

# %%
df_artikel.tail()
# Out:
#                                                 judul  \
# 95  Lecce Vs Roma: Menang 4-0, I Lupi ke Puncak Kl...
# 96                              Roma 'Rasa' Argentina
# 97  Nyetel di Como, Anak Eks Pelatih Timnas Indone...
# 98             Fiorentina Batal Pinjam Joshua Zirkzee
# 99       Chivu: Stones dan Jones Masih Butuh Adaptasi
#
#                                                   url
# 95  https://sport.detik.com/sepakbola/liga-italia/...
# 96  https://sport.detik.com/sepakbola/liga-italia/...
# 97  https://sport.detik.com/sepakbola/liga-italia/...
# 98  https://sport.detik.com/sepakbola/liga-italia/...
# 99  https://sport.detik.com/sepakbola/liga-italia/...
