# %%
# !pip install requests beautifulsoup4 pandas lxml tqdm
# Out:
# Requirement already satisfied: requests in c:\ppw\env_webmining\lib\site-packages (2.34.2)
# Requirement already satisfied: beautifulsoup4 in c:\ppw\env_webmining\lib\site-packages (4.15.0)
# Requirement already satisfied: pandas in c:\ppw\env_webmining\lib\site-packages (3.0.5)
# Requirement already satisfied: lxml in c:\ppw\env_webmining\lib\site-packages (6.1.3)
# Requirement already satisfied: tqdm in c:\ppw\env_webmining\lib\site-packages (4.70.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\ppw\env_webmining\lib\site-packages (from requests) (3.5.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\ppw\env_webmining\lib\site-packages (from requests) (3.19)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\ppw\env_webmining\lib\site-packages (from requests) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\ppw\env_webmining\lib\site-packages (from requests) (2026.7.22)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\ppw\env_webmining\lib\site-packages (from beautifulsoup4) (2.9.2)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\ppw\env_webmining\lib\site-packages (from beautifulsoup4) (4.16.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\ppw\env_webmining\lib\site-packages (from pandas) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\ppw\env_webmining\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\ppw\env_webmining\lib\site-packages (from pandas) (2026.3)
# Requirement already satisfied: colorama in c:\ppw\env_webmining\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\ppw\env_webmining\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip available: 22.3 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from tqdm import tqdm
from urllib.parse import urljoin
import time

# %%
urls = [
    "https://finance.detik.com/fintech",
    "https://finance.detik.com/infrastruktur"
]

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/139.0.0.0 Safari/537.36"
}

for url in urls:
    response = requests.get(url, headers=headers, timeout=10)

    print("URL:", url)
    print("Status Code:", response.status_code)
    print("Panjang halaman:", len(response.text))
    print("-" * 50)
# Out:
# URL: https://finance.detik.com/fintech
# Status Code: 200
# Panjang halaman: 317345
# --------------------------------------------------
# URL: https://finance.detik.com/infrastruktur
# Status Code: 200
# Panjang halaman: 323342
# --------------------------------------------------

# %%
for url in urls:
    response = requests.get(url, headers=headers, timeout=10)
    
    soup = BeautifulSoup(response.text, "html.parser")
    
    print("URL:", url)
    print("Judul halaman:", soup.title.get_text(strip=True))
    print("-" * 50)
# Out:
# URL: https://finance.detik.com/fintech
# Judul halaman: Info Berita Terkini Fintech, Startup, Bitcoin
# --------------------------------------------------
# URL: https://finance.detik.com/infrastruktur
# Judul halaman: detikFinance - Berita Ekonomi Bisnis, dan Investasi Hari Ini
# --------------------------------------------------

# %%
data_link = []

for url in urls:
    response = requests.get(url, headers=headers, timeout=10)
    soup = BeautifulSoup(response.text, "html.parser")
    
    links = soup.find_all("a", href=True)

    for link in links:
        href = link["href"]
        text = link.get_text(" ", strip=True)

        if (
            "finance.detik.com/fintech/" in href
            or "finance.detik.com/infrastruktur/" in href
        ):
            if "/d-" in href and text:
                data_link.append({
                    "judul": text,
                    "url": href
                })

    print("Selesai crawling:", url)

df_link = pd.DataFrame(data_link)

# Hilangkan URL yang sama
df_link = df_link.drop_duplicates(subset="url")

# Reset index
df_link = df_link.reset_index(drop=True)

print("Total artikel:", len(df_link))

df_link.head(10)
# Out:
# Selesai crawling: https://finance.detik.com/fintech
# 100  https://finance.detik.com/infrastruktur/d-8631...
#
# [101 rows x 2 columns]

# %%
df_artikel = df_link[
    (
        df_link["url"].str.contains("/fintech/", na=False)
        |
        df_link["url"].str.contains("/infrastruktur/", na=False)
    )
    &
    df_link["url"].str.contains("/d-", na=False)
].copy()

# Hilangkan URL duplikat
df_artikel = df_artikel.drop_duplicates(subset="url")

# Reset index
df_artikel = df_artikel.reset_index(drop=True)

print("Jumlah artikel fintech + infrastruktur:", len(df_artikel))
# Out:
# Jumlah artikel fintech + infrastruktur: 101

# %%
df_artikel.head(10)
# Out:
#                                                judul  \
# 0  Nilai Transaksi Aset Kripto RI Turun 28% Jadi ...
# 1  Mendag Ungkap Cara RI Bentuk Bursa Mineral, Ti...
# 2              Transaksi Kripto RI Tembus Rp 20,52 T
# 3      Bitcoin Masih Diminati Investor, Ini Tandanya
# 4  Keuntungan Gadai BPKB Motor Saat Kebutuhan Dan...
# 5  6 Cara Memilih Aplikasi Pinjaman Online Bunga ...
# 6  Bitcoin Terbang ke Level US$ 80.000, Ini Penye...
# 7  Bisalunas Ungkap 6 Mitos Galbay Pinjol yang Wa...
# 8  Industri Kripto Masuk Babak Baru, Regulasi dan...
# 9  Pengguna Kripto RI Tembus 22 Juta, Industri Bu...
#
#                                                  url
# 0  https://finance.detik.com/fintech/d-8652464/ni...
# 1  https://finance.detik.com/fintech/d-8636465/me...
# 2  https://finance.detik.com/fintech/d-8636301/tr...
# 3  https://finance.detik.com/fintech/d-8655330/bi...
# 4  https://finance.detik.com/fintech/d-8646895/ke...
# 5  https://finance.detik.com/fintech/d-8644968/6-...
# 6  https://finance.detik.com/fintech/d-8637573/bi...
# 7  https://finance.detik.com/fintech/d-8634417/bi...
# 8  https://finance.detik.com/fintech/d-8632680/in...
# 9  https://finance.detik.com/fintech/d-8630795/pe...

# %%
df_artikel = df_artikel.head(100)

print("Jumlah artikel yang akan di-crawl:", len(df_artikel))
# Out:
# Jumlah artikel yang akan di-crawl: 100

# %%
df_artikel.tail()
# Out:
#                                                 judul  \
# 95  LRT Manggarai ke Kelapa Gading Siap Beroperasi...
# 96  Tarif LRT Kelapa Gading-Manggarai Rp 5.000 Cum...
# 97  Pengoperasian Rute Baru LRT ke Manggarai Tungg...
# 98  Jauh-Dekat Sama, Tarif LRT Manggarai ke Kelapa...
# 99        KAI Poles Stasiun Cikampek, Begini Hasilnya
#
#                                                   url
# 95  https://finance.detik.com/infrastruktur/d-8634...
# 96  https://finance.detik.com/infrastruktur/d-8633...
# 97  https://finance.detik.com/infrastruktur/d-8633...
# 98  https://finance.detik.com/infrastruktur/d-8633...
# 99  https://finance.detik.com/infrastruktur/d-8633...
